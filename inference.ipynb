# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import os, glob
from PIL import Image
# from statistics import median, mean
from tensorflow.keras import Sequential
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Conv2D, Flatten, Dense, Dropout, MaxPooling2D, BatchNormalization, Activation
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.initializers import HeNormal
from tensorflow.keras.regularizers import l1_l2
import random
from matplotlib.image import imread

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Download file image URL menggunakan powershell Invoke-WebRequest

# %%
# !powershell Invoke-WebRequest -Uri "https://imgx.motorplus-online.com/crop/0x0:0x0/700x465/photo/2021/10/11/geger-harga-sepatu-nike-michael-20211011113406.jpg" -OutFile "img/image.jpg"

# !powershell Invoke-WebRequest -Uri "https://cdn.shopify.com/s/files/1/0516/0760/1336/files/3._Sepatu_Nike_Cortez_yang_legendaris_1000x1000.png?v=1690277361" -OutFile "img/image2.jpg"

# !powershell Invoke-WebRequest -Uri "https://www.static-src.com/wcsstore/Indraprastha/images/catalog/full/MTA-54221067/adidas_originals_adidas_superstar_originals_shoes_sepatu_pria_-eg4959-_full02_jaq9ddgd.jpeg" -OutFile "img/image3.jpg"


# !powershell Invoke-WebRequest -Uri "https://www.planetsports.asia/media/catalog/product/cache/144a401d4eb9f312744987a3cea154c3/0/1/01-NIKE-FFSSBNIK5-NIKFJ5437133-White.jpg" -OutFile "img/image4.jpg"

# !powershell Invoke-WebRequest -Uri "https://cdn-images.farfetch-contents.com/16/29/13/05/16291305_31975840_600.jpg" -OutFile "img/image5.jpg"

# !powershell Invoke-WebRequest -Uri "https://assets.ajio.com/medias/sys_master/root/20230807/qccn/64d0b9b6eebac147fcac6ee7/-473Wx593H-469496424-white-MODEL.jpg" -OutFile "img/image6.jpg"

# %%
from keras.models import load_model
import numpy as np
from keras.preprocessing import image

# Load the model
loaded_model = load_model('model_2.h5')

# Load and preprocess the image
img_path = 'img/image6.jpg'
img = image.load_img(img_path, target_size=(150, 150))  # Provide the target size
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0  # Normalize the pixel values

# Make predictions
predictions = loaded_model.predict(img_array)

# Apply threshold to predictions
model_pred_final = np.where(predictions >= 0.35, 1, 0)

# Display the image
plt.imshow(img)
plt.title('Original Image')
plt.show()

print('Prediction is a {}'.format('adidas' if model_pred_final[0][0] == 0 else 'nike'))
# Out:
# 1/1 [==============================] - 5s 5s/step
# Prediction is a adidas

# %%
from keras.models import load_model
import numpy as np
from keras.preprocessing import image

# Load the model
loaded_model = load_model('model_2.h5')

# Load and preprocess the image
img_path = 'img/image2.jpg'
img = image.load_img(img_path, target_size=(150, 150))  # Provide the target size
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)
img_array /= 255.0  # Normalize the pixel values

# Make predictions
predictions = loaded_model.predict(img_array)

# Apply threshold to predictions
model_pred_final = np.where(predictions >= 0.35, 1, 0)

# Display the image
plt.imshow(img)
plt.title('Original Image')
plt.show()

print('Prediction is a {}'.format('adidas' if model_pred_final[0][0] == 0 else 'nike'))
# Out:
# 1/1 [==============================] - 4s 4s/step
# Prediction is a nike
